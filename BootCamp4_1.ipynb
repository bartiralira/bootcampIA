# %% [markdown]
# ***Participantes (RM - NOME):***<br>
# Vitor Luiz Carvalhal - 337129<br>
# Ricardo Fabbro Antonelli - 339505<br>
# Bartira Lira Lafiandre - 340177<br>
# Tiago Batista Pessoa - 339575<br>

# %% [markdown]
# ## **0.Biblioteca e afins**

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential,load_model
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# !git clone https://github.com/bartiralira/bootcampIA.git
# Out:
# Cloning into 'bootcampIA'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (257/257), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 257 (delta 132), reused 138 (delta 67), pack-reused 0
# Receiving objects: 100% (257/257), 27.29 MiB | 21.04 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %% [markdown]
# # **Previsão diária**

# %% [markdown]
# ## **1.Importando os dados**

# %%
np.random.seed(7)

#Carrega o dataset
#international airline passengers problem with time step regression framing
dataframe_dia = read_csv('/content/bootcampIA/data/serie_temporal.csv', engine='python', delimiter= ';')
dataframe_dia.head()
# Out:
#                data
# 03/02/2020    50000
# 04/02/2020  1243000
# 05/02/2020  2952000
# 06/02/2020  5545000
# 07/02/2020  4685000

# %% [markdown]
# ## **2.Analisando os dados**

# %%
X = dataframe_dia.values
X = X.astype('float32')

# %%
dataframe_dia.describe()
# Out:
#                data
# count  3.890000e+02
# mean   3.692905e+06
# std    4.793278e+06
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.990000e+06
# 75%    5.665000e+06
# max    2.989260e+07

# %%
plt.figure(figsize=(10,8))
plt.plot(dataframe_dia)

# %%
X = X[350:len(X),:]

# %%
plt.figure(figsize=(10,8))
plt.plot(X)

# %%
#Normaliza o dataset
scaler = MinMaxScaler(feature_range=(0, 1))

#scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

train = X[0:train_size,:]
test =  X[train_size:len(X),:]

# %%
train.shape
# Out:
# (31, 1)

# %%
test.shape
# Out:
# (8, 1)

# %%
plt.plot(train)

# %%
plt.plot(test)

# %%
# quantidade de atrasos
look_back = 3

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
(X_train, x_valid) = X_train[100:], X_train[:100]
(y_train, y_valid) = y_train[100:], y_train[:100]

# %%
# quantidade de atrasos
look_back = 3

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (27, 3)

# %%
# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
x_valid = np.reshape(x_valid, (x_valid.shape[0], x_valid.shape[1], 1))

# %%
print(X_train.shape, 'train samples')
print(X_test.shape, 'test samples')
print(x_valid.shape, 'validation samples')
# Out:
# (27, 3, 1) train samples
# (4, 3, 1) test samples
# (27, 3, 1) validation samples

# %%
X_train[1]
# Out:
# array([[0.32048002],
#        [0.42996076],
#        [0.42808396]], dtype=float32)

# %%
y_train[1]
# Out:
# 0.32844225

# %%
X_train.shape
# Out:
# (27, 3, 1)

# %% [markdown]
# ## **3.Criando modelo RSTM**

# %%
from keras.callbacks import ModelCheckpoint

# %%
# Cria e treina a rede LSTM
model = Sequential()
model.add(LSTM(8, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='Adamax', metrics = ['mae'])
#model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)

# %%
checkpointer = ModelCheckpoint(filepath='/content/bootcampIA/checkpoints/modelodia.hdf5', verbose=1,  save_best_only=True, monitor='val_mae') 

hist = model.fit(X_train, y_train, batch_size=1, epochs=100,validation_data=(x_valid, y_valid), callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 2s 22ms/step - loss: 0.1183 - mae: 0.2574 - val_loss: 0.1094 - val_mae: 0.2436
#
# Epoch 00001: val_mae improved from inf to 0.24364, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch
saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 50/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2047 - val_loss: 0.0524 - val_mae: 0.2044
#
# Epoch 00050: val_mae improved from 0.20443 to 0.20440, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 51/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2048 - val_loss: 0.0524 - val_mae: 0.2043
#
# Epoch 00051: val_mae improved from 0.20440 to 0.20433, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 52/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2046 - val_loss: 0.0524 - val_mae: 0.2044
#
# Epoch 00052: val_mae did not improve from 0.20433
# Epoch 53/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0529 - mae: 0.2053 - val_loss: 0.0524 - val_mae: 0.2043
#
# Epoch 00053: val_mae did not improve from 0.20433
# Epoch 54/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2046 - val_loss: 0.0524 - val_mae: 0.2044
#
# Epoch 00054: val_mae did not improve from 0.20433
# Epoch 55/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0527 - mae: 0.2047 - val_loss: 0.0524 - val_mae: 0.2042
#
# Epoch 00055: val_mae improved from 0.20433 to 0.20423, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 56/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0525 - mae: 0.2046 - val_loss: 0.0524 - val_mae: 0.2043
#
# Epoch 00056: val_mae did not improve from 0.20423
# Epoch 57/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0527 - mae: 0.2048 - val_loss: 0.0524 - val_mae: 0.2042
#
# Epoch 00057: val_mae improved from 0.20423 to 0.20415, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 58/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0528 - mae: 0.2051 - val_loss: 0.0524 - val_mae: 0.2043
#
# Epoch 00058: val_mae did not improve from 0.20415
# Epoch 59/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0530 - mae: 0.2048 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00059: val_mae improved from 0.20415 to 0.20409, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 60/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2044 - val_loss: 0.0524 - val_mae: 0.2042
#
# Epoch 00060: val_mae did not improve from 0.20409
# Epoch 61/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0527 - mae: 0.2047 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00061: val_mae did not improve from 0.20409
# Epoch 62/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0525 - mae: 0.2045 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00062: val_mae did not improve from 0.20409
# Epoch 63/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0528 - mae: 0.2050 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00063: val_mae improved from 0.20409 to 0.20407, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 64/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2043 - val_loss: 0.0524 - val_mae: 0.2040
#
# Epoch 00064: val_mae improved from 0.20407 to 0.20404, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 65/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0526 - mae: 0.2044 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00065: val_mae did not improve from 0.20404
# Epoch 66/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2044 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00066: val_mae did not improve from 0.20404
# Epoch 67/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2047 - val_loss: 0.0524 - val_mae: 0.2040
#
# Epoch 00067: val_mae improved from 0.20404 to 0.20402, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 68/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0528 - mae: 0.2048 - val_loss: 0.0524 - val_mae: 0.2041
#
# Epoch 00068: val_mae did not improve from 0.20402
# Epoch 69/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0524 - mae: 0.2042 - val_loss: 0.0524 - val_mae: 0.2040
#
# Epoch 00069: val_mae improved from 0.20402 to 0.20398, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 70/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0528 - mae: 0.2048 - val_loss: 0.0524 - val_mae: 0.2039
#
# Epoch 00070: val_mae improved from 0.20398 to 0.20392, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 71/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0526 - mae: 0.2043 - val_loss: 0.0524 - val_mae: 0.2038
#
# Epoch 00071: val_mae improved from 0.20392 to 0.20384, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 72/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2042 - val_loss: 0.0524 - val_mae: 0.2039
#
# Epoch 00072: val_mae did not improve from 0.20384
# Epoch 73/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0529 - mae: 0.2049 - val_loss: 0.0524 - val_mae: 0.2037
#
# Epoch 00073: val_mae improved from 0.20384 to 0.20375, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2040 - val_loss: 0.0523 - val_mae: 0.2039
#
# Epoch 00074: val_mae did not improve from 0.20375
# Epoch 75/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2041 - val_loss: 0.0523 - val_mae: 0.2038
#
# Epoch 00075: val_mae did not improve from 0.20375
# Epoch 76/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2043 - val_loss: 0.0523 - val_mae: 0.2038
#
# Epoch 00076: val_mae did not improve from 0.20375
# Epoch 77/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2041 - val_loss: 0.0523 - val_mae: 0.2038
#
# Epoch 00077: val_mae did not improve from 0.20375
# Epoch 78/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0527 - mae: 0.2044 - val_loss: 0.0524 - val_mae: 0.2038
#
# Epoch 00078: val_mae did not improve from 0.20375
# Epoch 79/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2042 - val_loss: 0.0523 - val_mae: 0.2037
#
# Epoch 00079: val_mae improved from 0.20375 to 0.20370, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 80/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0528 - mae: 0.2043 - val_loss: 0.0523 - val_mae: 0.2038
#
# Epoch 00080: val_mae did not improve from 0.20370
# Epoch 81/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00081: val_mae improved from 0.20370 to 0.20361, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2043 - val_loss: 0.0523 - val_mae: 0.2038
#
# Epoch 00082: val_mae did not improve from 0.20361
# Epoch 83/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00083: val_mae did not improve from 0.20361
# Epoch 84/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2044 - val_loss: 0.0523 - val_mae: 0.2037
#
# Epoch 00084: val_mae did not improve from 0.20361
# Epoch 85/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0524 - mae: 0.2036 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00085: val_mae improved from 0.20361 to 0.20359, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 86/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00086: val_mae improved from 0.20359 to 0.20358, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 87/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0528 - mae: 0.2046 - val_loss: 0.0523 - val_mae: 0.2037
#
# Epoch 00087: val_mae did not improve from 0.20358
# Epoch 88/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0524 - mae: 0.2038 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00088: val_mae improved from 0.20358 to 0.20358, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 89/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2040 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00089: val_mae improved from 0.20358 to 0.20351, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 90/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2042 - val_loss: 0.0523 - val_mae: 0.2036
#
# Epoch 00090: val_mae did not improve from 0.20351
# Epoch 91/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2042 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00091: val_mae improved from 0.20351 to 0.20349, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 92/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00092: val_mae did not improve from 0.20349
# Epoch 93/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0526 - mae: 0.2040 - val_loss: 0.0523 - val_mae: 0.2034
#
# Epoch 00093: val_mae improved from 0.20349 to 0.20344, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 94/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00094: val_mae did not improve from 0.20344
# Epoch 95/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0526 - mae: 0.2043 - val_loss: 0.0523 - val_mae: 0.2034
#
# Epoch 00095: val_mae improved from 0.20344 to 0.20339, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 96/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2038 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00096: val_mae did not improve from 0.20339
# Epoch 97/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00097: val_mae did not improve from 0.20339
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0526 - mae: 0.2042 - val_loss: 0.0523 - val_mae: 0.2034
#
# Epoch 00098: val_mae did not improve from 0.20339
# Epoch 99/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0525 - mae: 0.2039 - val_loss: 0.0523 - val_mae: 0.2035
#
# Epoch 00099: val_mae did not improve from 0.20339
# Epoch 100/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0526 - mae: 0.2038 - val_loss: 0.0523 - val_mae: 0.2034
#
# Epoch 00100: val_mae improved from 0.20339 to 0.20338, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5

# %% [markdown]
# ## **4.Analisando as métricas**

# %%
plt.figure(1)
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model = load_model("/content/bootcampIA/checkpoints/modelodia.hdf5")

# %%
score = model.evaluate(X_train, y_train, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.20338042080402374

# %%
# Predições
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 4020558.75 RMSE
# Test Score: 5715307.64 RMSE

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# %%
# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(X)-2, :] = testPredict

# %% [markdown]
# ## **5.Plotando resultados**

# %%
# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,8))
plt.plot(scaler.inverse_transform(X))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# ## **6.Conclusões**
#
# Devido a baixa quantidade de dados realizar uma previsão diária, torna - se impreciso assim não seria possível apenas com estes dados criar um modelo o qual entregue um insight aceitavel.
