# %% [markdown]
# ***Participantes (RM - NOME):***<br>
# Vitor Luiz Carvalhal - 337129<br>
# Ricardo Fabbro Antonelli - 339505<br>
# Bartira Lira Lafiandre - 340177<br>
# Tiago Batista Pessoa - 339575<br>

# %% [markdown]
# ## **0.Biblioteca e afins**

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential,load_model
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# !git clone https://github.com/bartiralira/bootcampIA.git
# Out:
# Cloning into 'bootcampIA'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 179 (delta 85), reused 99 (delta 44), pack-reused 0
# Receiving objects: 100% (179/179), 23.40 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %% [markdown]
# # **Previsão diária**

# %% [markdown]
# ## **1.Importando os dados**

# %%
np.random.seed(7)

#Carrega o dataset
#international airline passengers problem with time step regression framing
dataframe_dia = read_csv('/content/bootcampIA/data/serie_temporal.csv', engine='python', delimiter= ';')
dataframe_dia.head()
# Out:
#             data
# 03/02/2020     1
# 04/02/2020     5
# 05/02/2020    27
# 06/02/2020    33
# 07/02/2020    50

# %% [markdown]
# ## **2.Analisando os dados**

# %%
X = dataframe_dia.values
X = X.astype('float32')

# %%
dataframe_dia.describe()
# Out:
#              data
# count  389.000000
# mean    19.457584
# std     18.605547
# min      0.000000
# 25%      0.000000
# 50%     19.000000
# 75%     32.000000
# max    100.000000

# %%
plt.figure(figsize=(10,8))
plt.plot(dataframe_dia)

# %%
X = X[350:len(X),:]

# %%
plt.figure(figsize=(10,8))
plt.plot(X)

# %%
#Normaliza o dataset
scaler = MinMaxScaler(feature_range=(0, 1))

#scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

train = X[0:train_size,:]
test =  X[train_size:len(X),:]

# %%
train.shape
# Out:
# (31, 1)

# %%
test.shape
# Out:
# (8, 1)

# %%
plt.plot(train)

# %%
plt.plot(test)

# %%
# quantidade de atrasos
look_back = 3

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
(X_train, x_valid) = X_train[100:], X_train[:100]
(y_train, y_valid) = y_train[100:], y_train[:100]

# %%
# quantidade de atrasos
look_back = 3

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (27, 3)

# %%
# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
x_valid = np.reshape(x_valid, (x_valid.shape[0], x_valid.shape[1], 1))

# %%
print(X_train.shape, 'train samples')
print(X_test.shape, 'test samples')
print(x_valid.shape, 'validation samples')
# Out:
# (27, 3, 1) train samples
# (4, 3, 1) test samples
# (27, 3, 1) validation samples

# %%
X_train[1]
# Out:
# array([[0.31343284],
#        [0.5970149 ],
#        [0.44776118]], dtype=float32)

# %%
y_train[1]
# Out:
# 0.46268657

# %%
X_train.shape
# Out:
# (27, 3, 1)

# %% [markdown]
# ## **3.Criando modelo RSTM**

# %%
from keras.callbacks import ModelCheckpoint

# %%
# Cria e treina a rede LSTM
model = Sequential()
model.add(LSTM(8, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='Adamax', metrics = ['mae'])
#model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)

# %%
checkpointer = ModelCheckpoint(filepath='/content/bootcampIA/checkpoints/modelodia.hdf5', verbose=1,  save_best_only=True, monitor='val_mae') 

hist = model.fit(X_train, y_train, batch_size=1, epochs=100,validation_data=(x_valid, y_valid), callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 2s 22ms/step - loss: 0.1304 - mae: 0.2809 - val_loss: 0.1234 - val_mae: 0.2768
#
# Epoch 00001: val_mae improved from inf to 0.27677, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch
100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0711 - mae: 0.2266 - val_loss: 0.0705 - val_mae: 0.2257
#
# Epoch 00064: val_mae improved from 0.22633 to 0.22575, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 65/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0707 - mae: 0.2260 - val_loss: 0.0704 - val_mae: 0.2257
#
# Epoch 00065: val_mae improved from 0.22575 to 0.22572, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 66/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0706 - mae: 0.2262 - val_loss: 0.0702 - val_mae: 0.2257
#
# Epoch 00066: val_mae did not improve from 0.22572
# Epoch 67/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0704 - mae: 0.2260 - val_loss: 0.0701 - val_mae: 0.2255
#
# Epoch 00067: val_mae improved from 0.22572 to 0.22551, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 68/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0702 - mae: 0.2256 - val_loss: 0.0699 - val_mae: 0.2252
#
# Epoch 00068: val_mae improved from 0.22551 to 0.22518, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 69/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0702 - mae: 0.2256 - val_loss: 0.0697 - val_mae: 0.2246
#
# Epoch 00069: val_mae improved from 0.22518 to 0.22459, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 70/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0703 - mae: 0.2259 - val_loss: 0.0696 - val_mae: 0.2244
#
# Epoch 00070: val_mae improved from 0.22459 to 0.22445, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 71/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0699 - mae: 0.2246 - val_loss: 0.0694 - val_mae: 0.2237
#
# Epoch 00071: val_mae improved from 0.22445 to 0.22366, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 72/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0697 - mae: 0.2241 - val_loss: 0.0692 - val_mae: 0.2236
#
# Epoch 00072: val_mae improved from 0.22366 to 0.22365, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 73/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0697 - mae: 0.2242 - val_loss: 0.0691 - val_mae: 0.2228
#
# Epoch 00073: val_mae improved from 0.22365 to 0.22276, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0695 - mae: 0.2235 - val_loss: 0.0689 - val_mae: 0.2227
#
# Epoch 00074: val_mae improved from 0.22276 to 0.22272, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 75/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0695 - mae: 0.2237 - val_loss: 0.0688 - val_mae: 0.2228
#
# Epoch 00075: val_mae did not improve from 0.22272
# Epoch 76/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0689 - mae: 0.2225 - val_loss: 0.0686 - val_mae: 0.2221
#
# Epoch 00076: val_mae improved from 0.22272 to 0.22214, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 77/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0691 - mae: 0.2236 - val_loss: 0.0685 - val_mae: 0.2223
#
# Epoch 00077: val_mae did not improve from 0.22214
# Epoch 78/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0686 - mae: 0.2219 - val_loss: 0.0683 - val_mae: 0.2215
#
# Epoch 00078: val_mae improved from 0.22214 to 0.22148, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 79/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0685 - mae: 0.2219 - val_loss: 0.0681 - val_mae: 0.2211
#
# Epoch 00079: val_mae improved from 0.22148 to 0.22106, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 80/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0682 - mae: 0.2214 - val_loss: 0.0679 - val_mae: 0.2210
#
# Epoch 00080: val_mae improved from 0.22106 to 0.22102, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 81/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0681 - mae: 0.2213 - val_loss: 0.0678 - val_mae: 0.2210
#
# Epoch 00081: val_mae did not improve from 0.22102
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0681 - mae: 0.2213 - val_loss: 0.0676 - val_mae: 0.2203
#
# Epoch 00082: val_mae improved from 0.22102 to 0.22032, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 83/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0677 - mae: 0.2204 - val_loss: 0.0675 - val_mae: 0.2205
#
# Epoch 00083: val_mae did not improve from 0.22032
# Epoch 84/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0677 - mae: 0.2211 - val_loss: 0.0673 - val_mae: 0.2202
#
# Epoch 00084: val_mae improved from 0.22032 to 0.22017, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 85/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0675 - mae: 0.2200 - val_loss: 0.0671 - val_mae: 0.2195
#
# Epoch 00085: val_mae improved from 0.22017 to 0.21953, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 86/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0676 - mae: 0.2207 - val_loss: 0.0670 - val_mae: 0.2192
#
# Epoch 00086: val_mae improved from 0.21953 to 0.21916, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 87/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0675 - mae: 0.2196 - val_loss: 0.0669 - val_mae: 0.2184
#
# Epoch 00087: val_mae improved from 0.21916 to 0.21836, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 88/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0672 - mae: 0.2196 - val_loss: 0.0667 - val_mae: 0.2188
#
# Epoch 00088: val_mae did not improve from 0.21836
# Epoch 89/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0668 - mae: 0.2186 - val_loss: 0.0665 - val_mae: 0.2182
#
# Epoch 00089: val_mae improved from 0.21836 to 0.21821, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 90/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0669 - mae: 0.2183 - val_loss: 0.0663 - val_mae: 0.2179
#
# Epoch 00090: val_mae improved from 0.21821 to 0.21786, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 91/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0667 - mae: 0.2186 - val_loss: 0.0662 - val_mae: 0.2174
#
# Epoch 00091: val_mae improved from 0.21786 to 0.21743, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 92/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0663 - mae: 0.2180 - val_loss: 0.0661 - val_mae: 0.2176
#
# Epoch 00092: val_mae did not improve from 0.21743
# Epoch 93/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0664 - mae: 0.2177 - val_loss: 0.0659 - val_mae: 0.2170
#
# Epoch 00093: val_mae improved from 0.21743 to 0.21700, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 94/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0669 - mae: 0.2186 - val_loss: 0.0658 - val_mae: 0.2171
#
# Epoch 00094: val_mae did not improve from 0.21700
# Epoch 95/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0660 - mae: 0.2170 - val_loss: 0.0655 - val_mae: 0.2161
#
# Epoch 00095: val_mae improved from 0.21700 to 0.21606, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 96/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0657 - mae: 0.2162 - val_loss: 0.0654 - val_mae: 0.2158
#
# Epoch 00096: val_mae improved from 0.21606 to 0.21581, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 97/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0656 - mae: 0.2159 - val_loss: 0.0652 - val_mae: 0.2153
#
# Epoch 00097: val_mae improved from 0.21581 to 0.21535, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 98/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0655 - mae: 0.2156 - val_loss: 0.0651 - val_mae: 0.2148
#
# Epoch 00098: val_mae improved from 0.21535 to 0.21479, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 99/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0657 - mae: 0.2159 - val_loss: 0.0650 - val_mae: 0.2143
#
# Epoch 00099: val_mae improved from 0.21479 to 0.21435, saving model to /content/bootcampIA/checkpoints/modelodia.hdf5
# Epoch 100/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0655 - mae: 0.2158 - val_loss: 0.0648 - val_mae: 0.2148
#
# Epoch 00100: val_mae did not improve from 0.21435

# %% [markdown]
# ## **4.Analisando as métricas**

# %%
plt.figure(1)
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model = load_model("/content/bootcampIA/checkpoints/modelodia.hdf5")

# %%
score = model.evaluate(X_train, y_train, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.21434995532035828

# %%
# Predições
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 17.08 RMSE
# Test Score: 14.35 RMSE

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# %%
# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(X)-2, :] = testPredict

# %% [markdown]
# ## **5.Plotando resultados**

# %%
# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,8))
plt.plot(scaler.inverse_transform(X))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# ## **6.Conclusões**
#
# Devido a baixa quantidade de dados realizar uma previsão diária, torna - se impreciso assim não seria possível apenas com estes dados criar um modelo o qual entregue um insight aceitavel.
